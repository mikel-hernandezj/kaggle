# %% [markdown]
# # EDA and Data Visualization on Games Rating Dataset
#
# In this notebook we perform some EDA and data visualization on the Games Rating Dataset
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 0. Import basic libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

print("Libraries imported!!")
# Out:
# Libraries imported!!

# %% [markdown]
# ----------------------------------------------------------------------------------------
# ## 1. Load and read the dataset
#
# Here, we read the dataset and we find the shape of it as well as the colum names.

# %%
df = pd.read_csv('data/train_clened.csv')
df
# Out:
#       game_id                                              names  min_players  \
# 0       17526                                           Hecatomb            2
# 1         156                                 Wildlife Adventure            2
# 2        2397                                         Backgammon            2
# 3        8147                                          Maka Bana            2
# 4       92190                              Super Dungeon Explore            2
# ...       ...                                                ...          ...
# 2883   203417                    Exit: The Game – The Secret Lab            1
# 2884   217861                                        Paper Tales            2
# 2885   142555  The Lord of the Rings: The Two Towers Deck-Bui...            2
# 2886    15474                                           Zombiaki            2
# 2887   155708                                Tiny Epic Defenders            1
#
#       max_players  avg_time  min_time  max_time  year  geek_rating  num_votes  \
# 0               4        30        30        30  2005      5.70135        360
# 1               6        60        60        60  1985      5.92648        535
# 2               2        30        30        30 -3000      6.37107       9684
# 3               6        60        45        60  2003      5.90326        658
# 4               6       120       120       120  2011      6.37715       2338
# ...           ...       ...       ...       ...   ...          ...        ...
# 2883            6       150        45       150  2016      6.77218       2562
# 2884            5        30        30        30  2017      5.96386        426
# 2885            5        45        30        45  2013      5.89570        486
# 2886            2        15        15        15  2003      5.72251        685
# 2887            4        30        30        30  2015      6.04041       1970
#
#       age                                           mechanic  owned  \
# 0      15                                    Hand Management    748
# 1      10    Point to Point Movement, Route/Network Building    786
# 2       8  Betting/Wagering, Dice Rolling, Roll / Spin an...  14104
# 3      10  Secret Unit Deployment, Simultaneous Action Se...    897
# 4      10  Action Point Allowance System, Dice Rolling, M...   5182
# ...   ...                                                ...    ...
# 2883   12                                  Co-operative Play   5530
# 2884   12                     Card Drafting, Hand Management    641
# 2885   15                               Deck / Pool Building   1255
# 2886    8                     Card Drafting, Hand Management    897
# 2887   13  Action Point Allowance System, Area Control / ...   5225
#
#               category1                category2  \
# 0             Card Game   Collectible Components
# 1               Animals              Exploration
# 2     Abstract Strategy                     Dice
# 3              Bluffing                Card Game
# 4             Adventure              Exploration
# ...                 ...                      ...
# 2883          Deduction                   Puzzle
# 2884          Card Game                  Fantasy
# 2885          Card Game                  Fantasy
# 2886          Card Game                 Fighting
# 2887            Fantasy                 Medieval
#
#                                          designer
# 0                    Mike Elliott, Jonathan Tweet
# 1                  Wolfgang Kramer, Ursula Kramer
# 2                                    (Uncredited)
# 3                                François Haffner
# 4     Chris Birkenhagen, John Cadice, Deke Stella
# ...                                           ...
# 2883                     Inka Brand, Markus Brand
# 2884                                Masato Uesugi
# 2885                                    Matt Hyra
# 2886                Adam Mnich, Ignacy Trzewiczek
# 2887                                  Scott Almes
#
# [2888 rows x 16 columns]

# %%
print('There are', df.shape[0], 'rows and', df.shape[1], 'columns in the dataset.')
# Out:
# There are 2888 rows and 16 columns in the dataset.

# %%
print('The columns of the dataset are the following: ')
for col in df.columns.tolist() :
    print('-', col)
# Out:
# The columns of the dataset are the following:
# - game_id
# - names
# - min_players
# - max_players
# - avg_time
# - min_time
# - max_time
# - year
# - geek_rating
# - num_votes
# - age
# - mechanic
# - owned
# - category1
# - category2
# - designer

# %% [markdown]
# ----------------------------------------------------------------------------------------
# ## 2. Analyse basic descriptive statistics of the dataset.
#
# Here, we analyse the basic statistics of the attributes.

# %%
#get basic statistics of numerical attributes
df.describe(include=[np.number])
# Out:
#             game_id  min_players  max_players      avg_time     min_time  \
# count    2888.00000  2888.000000  2888.000000   2888.000000  2888.000000
# mean    88219.70187     1.995845     5.116343    130.494806    90.429363
# std     75871.73450     0.673089     7.707973    535.670472   234.543216
# min         2.00000     0.000000     0.000000      0.000000     0.000000
# 25%     11970.00000     2.000000     4.000000     30.000000    30.000000
# 50%     70724.00000     2.000000     4.000000     60.000000    45.000000
# 75%    158635.50000     2.000000     6.000000    120.000000    90.000000
# max    244115.00000     8.000000   200.000000  22500.000000  5400.000000
#
#            max_time         year  geek_rating     num_votes          age  \
# count   2888.000000  2888.000000  2888.000000   2888.000000  2888.000000
# mean     130.143352  2003.723684     6.106197   2105.022853    10.515582
# std      535.727800   108.117070     0.490954   4752.801518     3.320607
# min        0.000000 -3000.000000     5.640260     62.000000     0.000000
# 25%       30.000000  2004.000000     5.734005    283.000000     9.000000
# 50%       60.000000  2011.000000     5.928085    636.000000    12.000000
# 75%      120.000000  2014.000000     6.322508   1704.000000    12.000000
# max    22500.000000  2018.000000     8.501630  77062.000000    42.000000
#
#                owned
# count    2888.000000
# mean     3220.748269
# std      6477.746931
# min        65.000000
# 25%       655.750000
# 50%      1253.000000
# 75%      2853.500000
# max    108796.000000

# %%
#get basic statistics of categorical attributes
df.describe(include=[np.object])
# Out:
#                    names mechanic  category1   category2       designer
# count               2888     2888       2888        2888           2888
# unique              2877     1558         72          81           1662
# top     Cosmic Encounter     none  Card Game   Card Game  Reiner Knizia
# freq                   4       90        551         247             58

# %% [markdown]
# ----------------------------------------------------------------------------------------
# ## 3. Explore features distribution
#
# Here, we make some plots to get familiar with the features distributions of the dataset.

# %%
# plot numerical distributions
num_features = ['game_id','min_players','max_players','avg_time','min_time','max_time','year','geek_rating','num_votes','age','owned']
for f in num_features :
    plt.boxplot(df[f])
    plt.title(f)
    plt.grid()
    plt.show()

# %%
# plot numerical distributions
num_features = ['game_id','min_players','max_players','avg_time','min_time','max_time','year','geek_rating','num_votes','age','owned']
for f in num_features :
    df[f].plot(kind='hist', bins=20)
    plt.title(f)
    plt.grid()
    plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------
# ## 4. Analyse correlations between attributes
#
# Here, we make some heatmaps to represent the correlations between the attributes.

# %%
df_copy = df.copy()
# for f in cat_features :
#     df_copy[f] = df_copy[f].astype('category').cat.codes
# df_copy.dtypes

# %%
cors = abs(df_copy.corr(method='pearson'))
mask = np.zeros_like(cors, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
fig = plt.figure(figsize=(10,10))
sns.heatmap(cors, mask=mask, cmap= "Blues", vmax=1, vmin=0, square=True, linewidths=.5)
plt.show()
